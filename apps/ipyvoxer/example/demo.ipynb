# %%
from ipyvoxer import TransferFunction, Renderer, SliceView
from pyvoxer import Dataset

# %%
renderer = Renderer('OpenGL')
renderer.datasets.load_from_file("/home/ukabuer/Downloads/Library/voxer/d.json")

# %%
tfcn = TransferFunction()

# %%
tfcn
# Out:
# TransferFunction(points=[{'x': 0, 'y': 0, 'color': '#333333'}, {'x': 1, 'y': 1, 'color': '#333333'}])

# %%
renderer.add_dataset(name='tooth')
renderer.add_tfcn(tfcn.get())
renderer.add_volume(dataset=0, tfcn=0)
renderer.set_camera(width=300, height=300, pos=[0, 300, 0], up=[0,0,1], target=[0,0,0])

# %%
renderer
# Out:
# Renderer(backend='OpenGL', image=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xd…

# %%
d = renderer.datasets.get("tooth", "default", 0)

# %%
slice_view = SliceView(d)

# %%
slice_view.draw('z', 50)

# %%
single = Dataset.Load("/home/ukabuer/Downloads/volume/ET数据/ctl.mrc")
single_mark = Dataset.Load("/home/ukabuer/Downloads/volume/CTL_ImmunSynapse_seg/CTL_ImmunSynapse_granules.mrc")

# %%
et_slice_view = SliceView(single)

# %%
et_slice_view.add_mark(single_mark, "#ff0000")

# %%
et_slice_view.draw('z', 60)
